# %%
# flight_df.withColumn("partitionId",spark_partition_id()).groupBy("partitionId").count().show()
# df.rdd.getNumpartitions() 
# spark.conf.set("spark.sql.shuffle.partitions",<No_of_partitions>) -- default = 200

# %% [markdown]
# _Spark Memory Management :_
# - What is OOM in spark ?
# - why do we get driver OOM ?
# - What is driver overhead memory ?
# - Common reason to get driver OOM?
# - How to handle OOM ?
